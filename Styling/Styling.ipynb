# %%
import matplotlib.pyplot as plt
import scipy.misc
import numpy
# %matplotlib inline

# Style transfer
import styling

# %%
image = scipy.misc.imread('blue_bird.jpg', mode='RGB')
plt.imshow(image)

# %%
styled_image = styling.style(image, 'models/udnie')
plt.imshow(styled_image)
